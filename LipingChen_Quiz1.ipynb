# %%
print('My name is Liping Chen this is the first quiz for BIOS-584')
# Out:
# My name is Liping Chen this is the first quiz for BIOS-584

# %%
original = ['cat1', 'cat1', 'cat1']

# %%
lst1 = ['cat1', 'cat1', 'cat1']
lst1.append('cat2')
print("Question1.", lst1)
# Out:
# Question1. ['cat1', 'cat1', 'cat1', 'cat2']

# %%
lst2 = ['cat1', 'cat1', 'cat1']
lst2.clear()
print("Question2.", lst2)
# Out:
# Question2. []

# %%
lst3 = ['cat1', 'cat1', 'cat1']
print("Question3.", lst3.copy())
# Out:
# Question3. ['cat1', 'cat1', 'cat1']

# %%
lst4 = ['cat1', 'cat1', 'cat2']
print("Question4.", lst4.count('cat1'))
# Out:
# Question4. 2

# %%
lst5 = ['cat1', 'cat1', 'cat2']
print("Question5.", lst5.index('cat2'))
# Out:
# Question5. 2

# %%
lst6 = ['cat1', 'cat1', 'cat1']
lst6.insert(1, 'cat2')
print("Question6.", lst6)
# Out:
# Question6. ['cat1', 'cat2', 'cat1', 'cat1']

# %%
lst7 = ['cat1', 'cat1', 'cat2']
lst7.pop(2)
print("Question7.", lst7)
# Out:
# Question7. ['cat1', 'cat1']

# %%
lst8 = ['cat1', 'cat1', 'cat2']
lst8.remove('cat2')
print("Question8.", lst8)
# Out:
# Question8. ['cat1', 'cat1']

# %%
lst9 = ['cat1', 'cat1', 'cat2']
lst9.reverse()
print("Question9.", lst9)
# Out:
# Question9. ['cat2', 'cat1', 'cat1']
